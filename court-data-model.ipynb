# %% [markdown]
# Downloaded "All court data" from https://www.courtlistener.com/api/bulk-data/courts/all.tar.gz and put it in the directory courts-all

# %%
import requests
from bs4 import BeautifulSoup

# %%
try:
    # getting list of federal court circuits and districts from file
    f = open('./html/USFedCircuitComposition.html')
    page = f.read()
    assert len(page) > 100
    soup = BeautifulSoup(page, 'html.parser')
    
except:
    print("List of federal court circuits and districts not found, retrieving from Wikipedia instead")
    r = requests.get('https://en.m.wikipedia.org/w/index.php?title=Template:USFedCircuitComposition&mobileaction=toggle_view_mobile')
    # saving the list to a file
    f = open('./html/USFedCircuitComposition.html', "w")
    f.write(r.text)
    soup = BeautifulSoup(r.text, 'html.parser')
# Out:
# list of federal court circuits and districts not found, retrieving from Wikipedia instead

# %%
fedTable = soup.table

# %%
import pprint

appealsTo = {}

for line in fedTable.find_all(['p', 'li']):
    if line.a.get('title') != None:
        title = line.a.get('title').strip()
        if title.startswith('United States Court of Appeals') and title.endswith('Circuit'):
            circuit = title
        if title == circuit:
            appealsTo[title] = "Supreme Court of the United States"
        else:
            appealsTo[title] = circuit
            
pprint.pprint(appealsTo)
# Out:
# {'Armed Services Board of Contract Appeals': 'United States Court of Appeals '
#                                              'for the Federal Circuit',
#  'Bureau of Justice Assistance': 'United States Court of Appeals for the '
#                                  'Federal Circuit',
#  'Civilian Board of Contract Appeals': 'United States Court of Appeals for the '
#                                        'Federal Circuit',
#  'District Court for the Northern Mariana Islands': 'United States Court of '
#                                                     'Appeals for the Ninth '
#                                                     'Circuit',
#  'District Court of Guam': 'United States Court of Appeals for the Ninth '
#                            'Circuit',
#  'District Court of the Virgin Islands': 'United States Court of Appeals for '
#                                          'the Third Circuit',
#  'Government Accountability Office': 'United States Court of Appeals for the '
#                                      'Federal Circuit',
#  'Patent Trial and Appeal Board': 'United States Court of Appeals for the '
#                                   'Federal Circuit',
#  'Trademark Trial and Appeal Board': 'United States Court of Appeals for the '
#                                      'Federal Circuit',
#  'United States Congress Office of Compliance': 'United States Court of '
#                                                 'Appeals for the Federal '
#                                                 'Circuit',
#  'United States Court of Appeals for Veterans Claims': 'United States Court of '
#                                                        'Appeals for the '
#                                                        'Federal Circuit',
#  'United States Court of Appeals for the District of Columbia Circuit': 'Supreme '
#                                                                         'Court '
#                                                                         'of '
#                                                                         'the '
#                                                                         'United '
#                                                                         'States',
#  'United States Court of Appeals for the Eighth Circuit': 'Supreme Court of '
#                                                           'the United States',
#  'United States Court of Appeals for the Eleventh Circuit': 'Supreme Court of '
#                                                             'the United States',
#  'United States Court of Appeals for the Federal Circuit': 'Supreme Court of '
#                                                            'the United States',
#  'United States Court of Appeals for the Fifth Circuit': 'Supreme Court of the '
#                                                          'United States',
#  'United States Court of Appeals for the First Circuit': 'Supreme Court of the '
#                                                          'United States',
#  'United States Court of Appeals for the Fourth Circuit': 'Supreme Court of '
#                                                           'the United States',
#  'United States Court of Appeals for the Ninth Circuit': 'Supreme Court of the '
#                                                          'United States',
#  'United States Court of Appeals for the Second Circuit': 'Supreme Court of '
#                                                           'the United States',
#  'United States Court of Appeals for the Seventh Circuit': 'Supreme Court of '
#                                                            'the United States',
#  'United States Court of Appeals for the Sixth Circuit': 'Supreme Court of the '
#                                                          'United States',
#  'United States Court of Appeals for the Tenth Circuit': 'Supreme Court of the '
#                                                          'United States',
#  'United States Court of Appeals for the Third Circuit': 'Supreme Court of the '
#                                                          'United States',
#  'United States Court of Federal Claims': 'United States Court of Appeals for '
#                                           'the Federal Circuit',
#  'United States Court of International Trade': 'United States Court of Appeals '
#                                                'for the Federal Circuit',
#  'United States District Court for the Central District of California': 'United '
#                                                                         'States '
#                                                                         'Court '
#                                                                         'of '
#                                                                         'Appeals '
#                                                                         'for '
#                                                                         'the '
#                                                                         'Ninth '
#                                                                         'Circuit',
#  'United States District Court for the Central District of Illinois': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Seventh '
#                                                                       'Circuit',
#  'United States District Court for the District of Alaska': 'United States '
#                                                             'Court of Appeals '
#                                                             'for the Ninth '
#                                                             'Circuit',
#  'United States District Court for the District of Arizona': 'United States '
#                                                              'Court of Appeals '
#                                                              'for the Ninth '
#                                                              'Circuit',
#  'United States District Court for the District of Colorado': 'United States '
#                                                               'Court of '
#                                                               'Appeals for the '
#                                                               'Tenth Circuit',
#  'United States District Court for the District of Columbia': 'United States '
#                                                               'Court of '
#                                                               'Appeals for the '
#                                                               'District of '
#                                                               'Columbia '
#                                                               'Circuit',
#  'United States District Court for the District of Connecticut': 'United '
#                                                                  'States Court '
#                                                                  'of Appeals '
#                                                                  'for the '
#                                                                  'Second '
#                                                                  'Circuit',
#  'United States District Court for the District of Delaware': 'United States '
#                                                               'Court of '
#                                                               'Appeals for the '
#                                                               'Third Circuit',
#  'United States District Court for the District of Hawaii': 'United States '
#                                                             'Court of Appeals '
#                                                             'for the Ninth '
#                                                             'Circuit',
#  'United States District Court for the District of Idaho': 'United States '
#                                                            'Court of Appeals '
#                                                            'for the Ninth '
#                                                            'Circuit',
#  'United States District Court for the District of Kansas': 'United States '
#                                                             'Court of Appeals '
#                                                             'for the Tenth '
#                                                             'Circuit',
#  'United States District Court for the District of Maine': 'United States '
#                                                            'Court of Appeals '
#                                                            'for the First '
#                                                            'Circuit',
#  'United States District Court for the District of Maryland': 'United States '
#                                                               'Court of '
#                                                               'Appeals for the '
#                                                               'Fourth Circuit',
#  'United States District Court for the District of Massachusetts': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'First '
#                                                                    'Circuit',
#  'United States District Court for the District of Minnesota': 'United States '
#                                                                'Court of '
#                                                                'Appeals for '
#                                                                'the Eighth '
#                                                                'Circuit',
#  'United States District Court for the District of Montana': 'United States '
#                                                              'Court of Appeals '
#                                                              'for the Ninth '
#                                                              'Circuit',
#  'United States District Court for the District of Nebraska': 'United States '
#                                                               'Court of '
#                                                               'Appeals for the '
#                                                               'Eighth Circuit',
#  'United States District Court for the District of Nevada': 'United States '
#                                                             'Court of Appeals '
#                                                             'for the Ninth '
#                                                             'Circuit',
#  'United States District Court for the District of New Hampshire': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'First '
#                                                                    'Circuit',
#  'United States District Court for the District of New Jersey': 'United States '
#                                                                 'Court of '
#                                                                 'Appeals for '
#                                                                 'the Third '
#                                                                 'Circuit',
#  'United States District Court for the District of New Mexico': 'United States '
#                                                                 'Court of '
#                                                                 'Appeals for '
#                                                                 'the Tenth '
#                                                                 'Circuit',
#  'United States District Court for the District of North Dakota': 'United '
#                                                                   'States '
#                                                                   'Court of '
#                                                                   'Appeals for '
#                                                                   'the Eighth '
#                                                                   'Circuit',
#  'United States District Court for the District of Oregon': 'United States '
#                                                             'Court of Appeals '
#                                                             'for the Ninth '
#                                                             'Circuit',
#  'United States District Court for the District of Puerto Rico': 'United '
#                                                                  'States Court '
#                                                                  'of Appeals '
#                                                                  'for the '
#                                                                  'First '
#                                                                  'Circuit',
#  'United States District Court for the District of Rhode Island': 'United '
#                                                                   'States '
#                                                                   'Court of '
#                                                                   'Appeals for '
#                                                                   'the First '
#                                                                   'Circuit',
#  'United States District Court for the District of South Carolina': 'United '
#                                                                     'States '
#                                                                     'Court of '
#                                                                     'Appeals '
#                                                                     'for the '
#                                                                     'Fourth '
#                                                                     'Circuit',
#  'United States District Court for the District of South Dakota': 'United '
#                                                                   'States '
#                                                                   'Court of '
#                                                                   'Appeals for '
#                                                                   'the Eighth '
#                                                                   'Circuit',
#  'United States District Court for the District of Utah': 'United States Court '
#                                                           'of Appeals for the '
#                                                           'Tenth Circuit',
#  'United States District Court for the District of Vermont': 'United States '
#                                                              'Court of Appeals '
#                                                              'for the Second '
#                                                              'Circuit',
#  'United States District Court for the District of Wyoming': 'United States '
#                                                              'Court of Appeals '
#                                                              'for the Tenth '
#                                                              'Circuit',
#  'United States District Court for the Eastern District of Arkansas': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eighth '
#                                                                       'Circuit',
#  'United States District Court for the Eastern District of California': 'United '
#                                                                         'States '
#                                                                         'Court '
#                                                                         'of '
#                                                                         'Appeals '
#                                                                         'for '
#                                                                         'the '
#                                                                         'Ninth '
#                                                                         'Circuit',
#  'United States District Court for the Eastern District of Kentucky': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Sixth '
#                                                                       'Circuit',
#  'United States District Court for the Eastern District of Louisiana': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Fifth '
#                                                                        'Circuit',
#  'United States District Court for the Eastern District of Michigan': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Sixth '
#                                                                       'Circuit',
#  'United States District Court for the Eastern District of Missouri': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eighth '
#                                                                       'Circuit',
#  'United States District Court for the Eastern District of New York': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Second '
#                                                                       'Circuit',
#  'United States District Court for the Eastern District of North Carolina': 'United '
#                                                                             'States '
#                                                                             'Court '
#                                                                             'of '
#                                                                             'Appeals '
#                                                                             'for '
#                                                                             'the '
#                                                                             'Fourth '
#                                                                             'Circuit',
#  'United States District Court for the Eastern District of Oklahoma': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Tenth '
#                                                                       'Circuit',
#  'United States District Court for the Eastern District of Pennsylvania': 'United '
#                                                                           'States '
#                                                                           'Court '
#                                                                           'of '
#                                                                           'Appeals '
#                                                                           'for '
#                                                                           'the '
#                                                                           'Third '
#                                                                           'Circuit',
#  'United States District Court for the Eastern District of Tennessee': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Sixth '
#                                                                        'Circuit',
#  'United States District Court for the Eastern District of Texas': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'Fifth '
#                                                                    'Circuit',
#  'United States District Court for the Eastern District of Virginia': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Fourth '
#                                                                       'Circuit',
#  'United States District Court for the Eastern District of Washington': 'United '
#                                                                         'States '
#                                                                         'Court '
#                                                                         'of '
#                                                                         'Appeals '
#                                                                         'for '
#                                                                         'the '
#                                                                         'Ninth '
#                                                                         'Circuit',
#  'United States District Court for the Eastern District of Wisconsin': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Seventh '
#                                                                        'Circuit',
#  'United States District Court for the Middle District of Alabama': 'United '
#                                                                     'States '
#                                                                     'Court of '
#                                                                     'Appeals '
#                                                                     'for the '
#                                                                     'Eleventh '
#                                                                     'Circuit',
#  'United States District Court for the Middle District of Florida': 'United '
#                                                                     'States '
#                                                                     'Court of '
#                                                                     'Appeals '
#                                                                     'for the '
#                                                                     'Eleventh '
#                                                                     'Circuit',
#  'United States District Court for the Middle District of Georgia': 'United '
#                                                                     'States '
#                                                                     'Court of '
#                                                                     'Appeals '
#                                                                     'for the '
#                                                                     'Eleventh '
#                                                                     'Circuit',
#  'United States District Court for the Middle District of Louisiana': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Fifth '
#                                                                       'Circuit',
#  'United States District Court for the Middle District of North Carolina': 'United '
#                                                                            'States '
#                                                                            'Court '
#                                                                            'of '
#                                                                            'Appeals '
#                                                                            'for '
#                                                                            'the '
#                                                                            'Fourth '
#                                                                            'Circuit',
#  'United States District Court for the Middle District of Pennsylvania': 'United '
#                                                                          'States '
#                                                                          'Court '
#                                                                          'of '
#                                                                          'Appeals '
#                                                                          'for '
#                                                                          'the '
#                                                                          'Third '
#                                                                          'Circuit',
#  'United States District Court for the Middle District of Tennessee': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Sixth '
#                                                                       'Circuit',
#  'United States District Court for the Northern District of Alabama': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eleventh '
#                                                                       'Circuit',
#  'United States District Court for the Northern District of California': 'United '
#                                                                          'States '
#                                                                          'Court '
#                                                                          'of '
#                                                                          'Appeals '
#                                                                          'for '
#                                                                          'the '
#                                                                          'Ninth '
#                                                                          'Circuit',
#  'United States District Court for the Northern District of Florida': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eleventh '
#                                                                       'Circuit',
#  'United States District Court for the Northern District of Georgia': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eleventh '
#                                                                       'Circuit',
#  'United States District Court for the Northern District of Illinois': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Seventh '
#                                                                        'Circuit',
#  'United States District Court for the Northern District of Indiana': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Seventh '
#                                                                       'Circuit',
#  'United States District Court for the Northern District of Iowa': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'Eighth '
#                                                                    'Circuit',
#  'United States District Court for the Northern District of Mississippi': 'United '
#                                                                           'States '
#                                                                           'Court '
#                                                                           'of '
#                                                                           'Appeals '
#                                                                           'for '
#                                                                           'the '
#                                                                           'Fifth '
#                                                                           'Circuit',
#  'United States District Court for the Northern District of New York': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Second '
#                                                                        'Circuit',
#  'United States District Court for the Northern District of Ohio': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'Sixth '
#                                                                    'Circuit',
#  'United States District Court for the Northern District of Oklahoma': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Tenth '
#                                                                        'Circuit',
#  'United States District Court for the Northern District of Texas': 'United '
#                                                                     'States '
#                                                                     'Court of '
#                                                                     'Appeals '
#                                                                     'for the '
#                                                                     'Fifth '
#                                                                     'Circuit',
#  'United States District Court for the Northern District of West Virginia': 'United '
#                                                                             'States '
#                                                                             'Court '
#                                                                             'of '
#                                                                             'Appeals '
#                                                                             'for '
#                                                                             'the '
#                                                                             'Fourth '
#                                                                             'Circuit',
#  'United States District Court for the Southern District of Alabama': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eleventh '
#                                                                       'Circuit',
#  'United States District Court for the Southern District of California': 'United '
#                                                                          'States '
#                                                                          'Court '
#                                                                          'of '
#                                                                          'Appeals '
#                                                                          'for '
#                                                                          'the '
#                                                                          'Ninth '
#                                                                          'Circuit',
#  'United States District Court for the Southern District of Florida': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eleventh '
#                                                                       'Circuit',
#  'United States District Court for the Southern District of Georgia': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eleventh '
#                                                                       'Circuit',
#  'United States District Court for the Southern District of Illinois': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Seventh '
#                                                                        'Circuit',
#  'United States District Court for the Southern District of Indiana': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Seventh '
#                                                                       'Circuit',
#  'United States District Court for the Southern District of Iowa': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'Eighth '
#                                                                    'Circuit',
#  'United States District Court for the Southern District of Mississippi': 'United '
#                                                                           'States '
#                                                                           'Court '
#                                                                           'of '
#                                                                           'Appeals '
#                                                                           'for '
#                                                                           'the '
#                                                                           'Fifth '
#                                                                           'Circuit',
#  'United States District Court for the Southern District of New York': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Second '
#                                                                        'Circuit',
#  'United States District Court for the Southern District of Ohio': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'Sixth '
#                                                                    'Circuit',
#  'United States District Court for the Southern District of Texas': 'United '
#                                                                     'States '
#                                                                     'Court of '
#                                                                     'Appeals '
#                                                                     'for the '
#                                                                     'Fifth '
#                                                                     'Circuit',
#  'United States District Court for the Southern District of West Virginia': 'United '
#                                                                             'States '
#                                                                             'Court '
#                                                                             'of '
#                                                                             'Appeals '
#                                                                             'for '
#                                                                             'the '
#                                                                             'Fourth '
#                                                                             'Circuit',
#  'United States District Court for the Western District of Arkansas': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eighth '
#                                                                       'Circuit',
#  'United States District Court for the Western District of Kentucky': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Sixth '
#                                                                       'Circuit',
#  'United States District Court for the Western District of Louisiana': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Fifth '
#                                                                        'Circuit',
#  'United States District Court for the Western District of Michigan': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Sixth '
#                                                                       'Circuit',
#  'United States District Court for the Western District of Missouri': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Eighth '
#                                                                       'Circuit',
#  'United States District Court for the Western District of New York': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Second '
#                                                                       'Circuit',
#  'United States District Court for the Western District of North Carolina': 'United '
#                                                                             'States '
#                                                                             'Court '
#                                                                             'of '
#                                                                             'Appeals '
#                                                                             'for '
#                                                                             'the '
#                                                                             'Fourth '
#                                                                             'Circuit',
#  'United States District Court for the Western District of Oklahoma': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Tenth '
#                                                                       'Circuit',
#  'United States District Court for the Western District of Pennsylvania': 'United '
#                                                                           'States '
#                                                                           'Court '
#                                                                           'of '
#                                                                           'Appeals '
#                                                                           'for '
#                                                                           'the '
#                                                                           'Third '
#                                                                           'Circuit',
#  'United States District Court for the Western District of Tennessee': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Sixth '
#                                                                        'Circuit',
#  'United States District Court for the Western District of Texas': 'United '
#                                                                    'States '
#                                                                    'Court of '
#                                                                    'Appeals '
#                                                                    'for the '
#                                                                    'Fifth '
#                                                                    'Circuit',
#  'United States District Court for the Western District of Virginia': 'United '
#                                                                       'States '
#                                                                       'Court '
#                                                                       'of '
#                                                                       'Appeals '
#                                                                       'for the '
#                                                                       'Fourth '
#                                                                       'Circuit',
#  'United States District Court for the Western District of Washington': 'United '
#                                                                         'States '
#                                                                         'Court '
#                                                                         'of '
#                                                                         'Appeals '
#                                                                         'for '
#                                                                         'the '
#                                                                         'Ninth '
#                                                                         'Circuit',
#  'United States District Court for the Western District of Wisconsin': 'United '
#                                                                        'States '
#                                                                        'Court '
#                                                                        'of '
#                                                                        'Appeals '
#                                                                        'for '
#                                                                        'the '
#                                                                        'Seventh '
#                                                                        'Circuit',
#  'United States International Trade Commission': 'United States Court of '
#                                                  'Appeals for the Federal '
#                                                  'Circuit',
#  'United States Merit Systems Protection Board': 'United States Court of '
#                                                  'Appeals for the Federal '
#                                                  'Circuit'}

# %%
# Turns the CourtListener format of federal court names into the format used by Wikipedia.

def longFedCircuitName(fullName):
    if fullName.startswith("Court of Appeals"):
        fullName = fullName.replace("Court of Appeals", "United States Court of Appeals", 1)
    return fullName

def longFedDistrictName(fullName):
    fullName = fullName.replace(",", " for the").replace("D.", "District of").replace("C.", "Central ").replace("M.", "Middle ")
    fullName = fullName.replace("E.", "Eastern ").replace("W.", "Western ").replace("S.", "Southern ").replace("N.", "Northern ")
    if not fullName.endswith(("Northern Mariana Islands","Guam","Virgin Islands")):
        if fullName.startswith("District Court"):
            fullName = fullName.replace("District Court", "United States District Court", 1)
    return fullName

def longFedCourtName(fullName, j):
    assert j in ('F', 'FD', 'FS')
    if j in ('FD', 'FS'):
        return longFedDistrictName(fullName)
    if j == 'F':
        return longFedCircuitName(fullName)

longFedCourtName('District Court, N.D. Mississippi', 'FD')
# Out:
# 'United States District Court for the Northern District of Mississippi'

# %%
import json, os

foldername = "./courts-all/"

courts = []

for dirpath, dirnames, filenames in os.walk(foldername):
    for filename in filenames:
        source = foldername + filename
        markup = open(source)
        court = json.load(markup)
        if "jurisdiction" in court:
            if court['jurisdiction'] in ('F', 'FD', 'FS'): # will need to import other kinds of courts later
                courts.append(court)

for court in courts:
    court['unabbreviated_name'] = longFedCourtName(court['full_name'], court['jurisdiction'])

# %%
# This is failing because I don't have a way to handle the defunct court
# A comprehensive solution would capture the date range that every court appealed to every other one...
# Remember to add WikiData URIs for each court
# This is fun!
                
for court in courts:
    if not court['appeals_to']:
        if court['unabbreviated_name'] == 'United States Supreme Court':
            court['appeals_to'] = None
        else:
            court['appeals_to'] = appealsTo[court['unabbreviated_name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-385db4632438> in <module>()
#       5
#       6 for court in courts:
# ----> 7     if not court['appeals_to']:
#       8         if court['unabbreviated_name'] == 'United States Supreme Court':
#       9             court['appeals_to'] = None
#
# KeyError: 'appeals_to'

# %%
appealsTo[longFedCourtName('District Court, N.D. California')]
# Out:
# 'United States Court of Appeals for the Ninth Circuit'

# %%
courts
# Out:
# [{'citation_string': 'W.D. Tex.',
#   'date_modified': '2013-10-22T15:56:39.023000Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Texas',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 251.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/txwd/',
#   'short_name': 'W.D. Texas',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Texas',
#   'url': 'http://www.txwd.uscourts.gov/'},
#  {'citation_string': 'N.D. Ind.',
#   'date_modified': '2017-04-21T21:42:23.700554Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Indiana',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 211.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/innd/',
#   'short_name': 'N.D. Indiana',
#   'start_date': '1928-04-21',
#   'unabbreviated_name': 'United States District Court for the Northern District of Indiana',
#   'url': 'http://www.innd.uscourts.gov/'},
#  {'citation_string': 'S.D. Ga.',
#   'date_modified': '2013-10-22T15:48:39.610000Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Georgia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 208.62,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/gasd/',
#   'short_name': 'S.D. Georgia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of Georgia',
#   'url': 'http://www.gasd.uscourts.gov/'},
#  {'citation_string': 'D. Cal.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': '1886-08-05',
#   'full_name': 'District Court, D. California',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 205.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/californiad/',
#   'short_name': 'D. California',
#   'start_date': '1866-07-27',
#   'unabbreviated_name': 'United States District Court for the District of California',
#   'url': 'http://www.uscourts.gov/'},
#  {'citation_string': 'D. Alaska',
#   'date_modified': '2013-08-15T17:49:55Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Alaska',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 202.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/akd/',
#   'short_name': 'D. Alaska',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Alaska',
#   'url': 'http://www.akd.uscourts.gov/'},
#  {'citation_string': 'D. Conn.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Connecticut',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 207.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ctd/',
#   'short_name': 'D. Connecticut',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Connecticut',
#   'url': 'http://www.ctd.uscourts.gov/'},
#  {'citation_string': 'D. Colo.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Colorado',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 206.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/cod/',
#   'short_name': 'D. Colorado',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Colorado',
#   'url': 'http://www.cod.uscourts.gov/'},
#  {'citation_string': 'M.D. Penn.',
#   'date_modified': '2013-10-22T15:25:27.235000Z',
#   'end_date': None,
#   'full_name': 'District Court, M.D. Pennsylvania',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 247.95,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/pamd/',
#   'short_name': 'M.D. Pennsylvania',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Middle District of Pennsylvania',
#   'url': 'http://www.pamd.uscourts.gov/'},
#  {'citation_string': 'MSPB',
#   'date_modified': '2014-09-02T23:05:21.019000Z',
#   'end_date': None,
#   'full_name': 'Merit Systems Protection Board',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 114.995,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mspb/',
#   'short_name': 'Merit Systems Protection Board',
#   'start_date': None,
#   'unabbreviated_name': 'Merit Systems Protection Board',
#   'url': 'http://www.mspb.gov/'},
#  {'citation_string': '10th Cir.',
#   'date_modified': '2013-08-14T16:46:30Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the Tenth Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 110.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ca10/',
#   'short_name': 'Tenth Circuit',
#   'start_date': '1929-02-28',
#   'unabbreviated_name': 'United States Court of Appeals for the Tenth Circuit',
#   'url': 'http://www.ca10.uscourts.gov/'},
#  {'citation_string': 'Emer. Ct. App.',
#   'date_modified': '2013-08-14T22:20:25Z',
#   'end_date': '1962-04-18',
#   'full_name': 'Emergency Court of Appeals',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 116.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/eca/',
#   'short_name': 'Emergency Court of Appeals',
#   'start_date': '1942-01-30',
#   'unabbreviated_name': 'Emergency Court of Appeals',
#   'url': 'https://secure.wikimedia.org/wikipedia/en/wiki/Emergency_Court_of_Appeals'},
#  {'citation_string': 'D. Del.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Delaware',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 208.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ded/',
#   'short_name': 'D. Delaware',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Delaware',
#   'url': 'http://www.ded.uscourts.gov/'},
#  {'citation_string': 'S.D. Ill.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Illinois',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 210.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ilsd/',
#   'short_name': 'S.D. Illinois',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of Illinois',
#   'url': 'http://www.ilsd.uscourts.gov/'},
#  {'citation_string': 'N.M.C.C.A.',
#   'date_modified': '2014-09-19T01:48:18.061000Z',
#   'end_date': None,
#   'full_name': 'Navy-Marine Corps Court of Criminal Appeals',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 114.996,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/nmcca/',
#   'short_name': 'Navy-Marine Corps Court of Criminal Appeals',
#   'start_date': None,
#   'unabbreviated_name': 'Navy-Marine Corps Court of Criminal Appeals',
#   'url': 'http://www.jag.navy.mil/'},
#  {'citation_string': 'C.C.P.A.',
#   'date_modified': '2013-08-14T22:19:17Z',
#   'end_date': '1982-04-02',
#   'full_name': 'Court of Customs and Patent Appeals',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 114.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ccpa/',
#   'short_name': 'Customs and Patent Appeals',
#   'start_date': '1909-08-05',
#   'unabbreviated_name': 'Court of Customs and Patent Appeals',
#   'url': 'http://www.cafc.uscourts.gov/'},
#  {'citation_string': 'N.D. Ala.',
#   'date_modified': '2013-08-15T05:35:30Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Alabama',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 201.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/alnd/',
#   'short_name': 'N.D. Alabama',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of Alabama',
#   'url': 'http://www.alnd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Kansas',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 228.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ksd/',
#   'short_name': 'D. Kansas',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Kansas',
#   'url': 'http://www.ksd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2013-10-22T15:50:02.654000Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Michigan',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 240.7,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/miwd/',
#   'short_name': 'W.D. Michigan',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Michigan',
#   'url': 'http://www.miwd.uscourts.gov/'},
#  {'citation_string': 'S.D. Miss.',
#   'date_modified': '2013-10-22T15:50:58.078000Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Mississippi',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 241.15,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mssd/',
#   'short_name': 'S.D. Mississippi',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of Mississippi',
#   'url': 'http://www.mssd.uscourts.gov/'},
#  {'citation_string': 'M.D. La.',
#   'date_modified': '2013-08-15T17:47:53Z',
#   'end_date': None,
#   'full_name': 'District Court, M.D. Louisiana',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 231.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/lamd/',
#   'short_name': 'M.D. Louisiana',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Middle District of Louisiana',
#   'url': 'http://www.lamd.uscourts.gov/'},
#  {'citation_string': 'D.N.D.',
#   'date_modified': '2013-08-15T16:04:07Z',
#   'end_date': None,
#   'full_name': 'District Court, D. North Dakota',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.3,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ndd/',
#   'short_name': 'D. North Dakota',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of North Dakota',
#   'url': 'http://www.ndd.uscourts.gov/'},
#  {'citation_string': 'N.D. Tex.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Texas',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 250.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/txnd/',
#   'short_name': 'N.D. Texas',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of Texas',
#   'url': 'http://www.txnd.uscourts.gov/'},
#  {'citation_string': 'S.D.N.Y.',
#   'date_modified': '2013-10-22T15:54:04.692000Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. New York',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/nysd/',
#   'short_name': 'S.D. New York',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of New York',
#   'url': 'http://www.nysd.uscourts.gov/'},
#  {'citation_string': 'W.D.N.C.',
#   'date_modified': '2013-10-22T15:54:24.087000Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. North Carolina',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.2,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ncwd/',
#   'short_name': 'W.D. North Carolina',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of North Carolina',
#   'url': 'http://www.ncwd.uscourts.gov/'},
#  {'citation_string': 'N.D. Ga.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Georgia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 208.61,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/gand/',
#   'short_name': 'N.D. Georgia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of Georgia',
#   'url': 'http://www.gand.uscourts.gov/'},
#  {'citation_string': 'Temp. Emerg. Ct. App.',
#   'date_modified': '2013-08-14T22:20:33Z',
#   'end_date': '1992-10-29',
#   'full_name': 'Temporary Emergency Court of Appeals',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 116.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/tecoa/',
#   'short_name': 'Temporary Emergency Court of Appeals',
#   'start_date': '1971-12-01',
#   'unabbreviated_name': 'Temporary Emergency Court of Appeals',
#   'url': 'http://www.fjc.gov/history/home.nsf/page/courts_special_tecoa.html'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:09:43.128193Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Mississippi',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 241.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/missd/',
#   'short_name': 'D. Mississippi',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Mississippi',
#   'url': ''},
#  {'citation_string': 'W.D.N.Y.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. New York',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.05,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/nywd/',
#   'short_name': 'W.D. New York',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of New York',
#   'url': 'http://www.nywd.uscourts.gov/'},
#  {'citation_string': 'S.D. Ind.',
#   'date_modified': '2017-04-21T21:42:36.535777Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Indiana',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 212.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/insd/',
#   'short_name': 'S.D. Indiana',
#   'start_date': '1928-04-21',
#   'unabbreviated_name': 'United States District Court for the Southern District of Indiana',
#   'url': 'http://www.insd.uscourts.gov/'},
#  {'citation_string': 'D. Or.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Oregon',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 247.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ord/',
#   'short_name': 'D. Oregon',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Oregon',
#   'url': 'http://www.ord.uscourts.gov/'},
#  {'citation_string': 'Fed. Cl.',
#   'date_modified': '2013-08-14T22:19:01Z',
#   'end_date': None,
#   'full_name': 'United States Court of Federal Claims',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 113.6,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/uscfc/',
#   'short_name': 'Federal Claims',
#   'start_date': '1982-04-02',
#   'unabbreviated_name': 'United States Court of Federal Claims',
#   'url': 'http://www.uscfc.uscourts.gov/'},
#  {'citation_string': 'Board of Vet. App.',
#   'date_modified': '2014-09-19T01:06:34.973000Z',
#   'end_date': None,
#   'full_name': "Board of Veterans' Appeals",
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 115.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/bva/',
#   'short_name': "Board of Veterans' Appeals",
#   'start_date': None,
#   'unabbreviated_name': "Board of Veterans' Appeals",
#   'url': 'http://www.index.va.gov/search/va/bva_search.jsp'},
#  {'citation_string': 'FISA Ct.',
#   'date_modified': '2014-05-27T15:58:47.570000Z',
#   'end_date': None,
#   'full_name': 'Foreign Intelligence Surveillance Court',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 140.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/fisc/',
#   'short_name': 'Foreign Intelligence Surveillance Court',
#   'start_date': '1978-10-25',
#   'unabbreviated_name': 'Foreign Intelligence Surveillance Court',
#   'url': 'http://www.fisc.uscourts.gov/'},
#  {'citation_string': 'N.D. Miss.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Mississippi',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 241.12,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/msnd/',
#   'short_name': 'N.D. Mississippi',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of Mississippi',
#   'url': 'http://www.msnd.uscourts.gov/'},
#  {'citation_string': 'D. Guam',
#   'date_modified': '2013-08-20T00:14:40Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Guam',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 299.3,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/gud/',
#   'short_name': 'D. Guam',
#   'start_date': None,
#   'unabbreviated_name': 'District Court for the District of Guam',
#   'url': 'http://www.gud.uscourts.gov/'},
#  {'citation_string': '11th Cir.',
#   'date_modified': '2013-08-14T16:46:30Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the Eleventh Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 111.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ca11/',
#   'short_name': 'Eleventh Circuit',
#   'start_date': '1980-10-14',
#   'unabbreviated_name': 'United States Court of Appeals for the Eleventh Circuit',
#   'url': 'http://www.ca11.uscourts.gov/'},
#  {'citation_string': 'D. Utah',
#   'date_modified': '2016-09-08T19:00:07.979979Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Utah',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 251.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/utd/',
#   'short_name': 'D. Utah',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Utah',
#   'url': 'http://www.utd.uscourts.gov/'},
#  {'citation_string': 'N.D. Ill.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Illinois',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 210.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ilnd/',
#   'short_name': 'N.D. Illinois',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of Illinois',
#   'url': 'http://www.ilnd.uscourts.gov/'},
#  {'citation_string': '1st Cir.',
#   'date_modified': '2014-10-31T01:57:47.787000Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the First Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': True,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 101.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ca1/',
#   'short_name': 'First Circuit',
#   'start_date': '1891-03-03',
#   'unabbreviated_name': 'United States Court of Appeals for the First Circuit',
#   'url': 'http://www.ca1.uscourts.gov/'},
#  {'citation_string': 'C.A.A.F.',
#   'date_modified': '2013-08-14T22:18:37Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the Armed Forces',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 113.2,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/armfor/',
#   'short_name': 'Court of Appeals for the Armed Forces',
#   'start_date': '1951-05-31',
#   'unabbreviated_name': 'Court of Appeals for the Armed Forces',
#   'url': 'http://www.armfor.uscourts.gov/'},
#  {'citation_string': 'D.C.',
#   'date_modified': '2014-05-20T00:58:40.714000Z',
#   'end_date': None,
#   'full_name': 'District Court, District of Columbia',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 200.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/dcd/',
#   'short_name': 'District of Columbia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Columbia',
#   'url': 'http://www.dcd.uscourts.gov/'},
#  {'citation_string': 'S.D. Ala.',
#   'date_modified': '2013-10-22T15:47:52.502000Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Alabama',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 202.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/alsd/',
#   'short_name': 'S.D. Alabama',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of Alabama',
#   'url': 'http://www.als.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2013-10-22T15:53:49.353000Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. New York',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 244.9,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/nynd/',
#   'short_name': 'N.D. New York',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of New York',
#   'url': 'http://www.nynd.uscourts.gov/'},
#  {'citation_string': 'S.D. Tex.',
#   'date_modified': '2013-10-22T15:56:25.488000Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Texas',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 250.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/txsd/',
#   'short_name': 'S.D. Texas',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of Texas',
#   'url': 'http://www.txs.uscourts.gov/'},
#  {'citation_string': 'D. Mont.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Montana',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 242.19,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mtd/',
#   'short_name': 'D. Montana',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Montana',
#   'url': 'http://www.mtd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:10:10.306159Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Missouri',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 241.4,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mod/',
#   'short_name': 'D. Missouri',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Missouri',
#   'url': ''},
#  {'citation_string': 'D. Wis.',
#   'date_modified': '2013-10-22T15:57:56.363000Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. Wisconsin',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 297.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/wied/',
#   'short_name': 'E.D. Wisconsin',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Eastern District of Wisconsin',
#   'url': 'http://www.wied.uscourts.gov/'},
#  {'citation_string': 'A.S.B.C.A.',
#   'date_modified': '2014-09-19T01:15:36.995000Z',
#   'end_date': None,
#   'full_name': 'Armed Services Board of Contract Appeals',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 113.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/asbca/',
#   'short_name': 'Armed Services Board of Contract Appeals',
#   'start_date': None,
#   'unabbreviated_name': 'Armed Services Board of Contract Appeals',
#   'url': 'http://www.asbca.mil/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:10:46.774205Z',
#   'end_date': None,
#   'full_name': 'District Court, D. New York',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 244.7,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/nyd/',
#   'short_name': 'D. New York',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of New York',
#   'url': ''},
#  {'citation_string': 'W.D. Tenn.',
#   'date_modified': '2013-10-22T15:56:11.964000Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Tennessee',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 249.8,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/tnwd/',
#   'short_name': 'W.D. Tennessee',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Tennessee',
#   'url': 'http://www.tnwd.uscourts.gov/'},
#  {'citation_string': 'C.D. Cal.',
#   'date_modified': '2013-08-20T00:00:54Z',
#   'end_date': None,
#   'full_name': 'District Court, C.D. California',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 205.05,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/cacd/',
#   'short_name': 'C.D. California',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Central District of California',
#   'url': 'http://www.cacd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:08:35.278109Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Louisiana',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 230.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/lad/',
#   'short_name': 'D. Louisiana',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Louisiana',
#   'url': ''},
#  {'citation_string': 'Fed. Cir.',
#   'date_modified': '2014-10-31T01:59:03.099000Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the Federal Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': True,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 113.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/cafc/',
#   'short_name': 'Federal Circuit',
#   'start_date': '1982-04-02',
#   'unabbreviated_name': 'United States Court of Appeals for the Federal Circuit',
#   'url': 'http://www.cafc.uscourts.gov/'},
#  {'citation_string': 'N. Mar. I.',
#   'date_modified': '2013-08-15T19:41:12Z',
#   'end_date': None,
#   'full_name': 'District Court, Northern Mariana Islands',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 299.4,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/nmid/',
#   'short_name': 'Northern Mariana Islands',
#   'start_date': None,
#   'unabbreviated_name': 'District Court for the Northern Mariana Islands',
#   'url': 'http://www.nmid.uscourts.gov/'},
#  {'citation_string': 'W.D. Okla.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Oklahoma',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 246.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/okwd/',
#   'short_name': 'W.D. Oklahoma',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Oklahoma',
#   'url': 'http://www.uscourts.gov/'},
#  {'citation_string': 'FISA Ct. Rev.',
#   'date_modified': '2014-05-27T15:58:53.457000Z',
#   'end_date': None,
#   'full_name': 'Foreign Intelligence Surveillance Court of Review',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 140.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/fiscr/',
#   'short_name': 'Foreign Intelligence Surveillance Court of Review',
#   'start_date': '1978-10-25',
#   'unabbreviated_name': 'Foreign Intelligence Surveillance Court of Review',
#   'url': 'http://www.fisc.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:09:13.812273Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Michigan',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 240.55,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/michd/',
#   'short_name': 'D. Michigan',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Michigan',
#   'url': ''},
#  {'citation_string': 'M.D.N.C.',
#   'date_modified': '2013-08-15T16:24:58Z',
#   'end_date': None,
#   'full_name': 'District Court, M.D. North Carolina',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.15,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ncmd/',
#   'short_name': 'M.D. North Carolina',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Middle District of North Carolina',
#   'url': 'http://www.ncmd.uscourts.gov/'},
#  {'citation_string': 'W.D. Mo.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Missouri',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 242.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mowd/',
#   'short_name': 'W.D. Missouri',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Missouri',
#   'url': 'http://www.mow.uscourts.gov/'},
#  {'citation_string': 'E.D. Ky.',
#   'date_modified': '2013-10-22T15:49:45.772000Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. Kentucky',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 229.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/kyed/',
#   'short_name': 'E.D. Kentucky',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Eastern District of Kentucky',
#   'url': 'http://www.kyed.uscourts.gov/'},
#  {'citation_string': 'D. Neb.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Nebraska',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 242.2,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ned/',
#   'short_name': 'D. Nebraska',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Nebraska',
#   'url': 'http://www.ned.uscourts.gov/'},
#  {'citation_string': 'W.D. La.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Louisiana',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 231.2,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/lawd/',
#   'short_name': 'W.D. Louisiana',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Louisiana',
#   'url': 'http://www.lawd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:11:48.069727Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Texas',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 249.95,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/texd/',
#   'short_name': 'D. Texas',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Texas',
#   'url': ''},
#  {'citation_string': 'E.D. Wash.',
#   'date_modified': '2013-10-22T15:57:02.054000Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. Washington',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 289.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/waed/',
#   'short_name': 'E.D. Washington',
#   'start_date': '1905-03-02',
#   'unabbreviated_name': 'United States District Court for the Eastern District of Washington',
#   'url': 'http://www.waed.uscourts.gov/'},
#  {'citation_string': 'E.D.S.C.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': '1965-10-07',
#   'full_name': 'District Court, E.D. South Carolina',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 249.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/southcarolinaed/',
#   'short_name': 'E.D. South Carolina',
#   'start_date': '1823-02-21',
#   'unabbreviated_name': 'United States District Court for the Eastern District of South Carolina',
#   'url': 'http://www.scd.uscourts.gov/'},
#  {'citation_string': 'Cir. Ct. Del.',
#   'date_modified': '2016-06-29T17:11:46.596000Z',
#   'end_date': '1912-01-01',
#   'full_name': 'U.S. Circuit Court for the District of Delaware',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 208.2,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/circtdel/',
#   'short_name': 'Circuit Court of Delaware',
#   'start_date': '1789-09-24',
#   'unabbreviated_name': 'U.Southern  Circuit Court for the District of Delaware',
#   'url': 'http://www.fjc.gov/history/home.nsf/page/courts_circuit_de.html'},
#  {'citation_string': 'M.D. Ala.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, M.D. Alabama',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 201.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/almd/',
#   'short_name': 'M.D. Alabama',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Middle District of Alabama',
#   'url': 'http://www.almd.uscourts.gov/'},
#  {'citation_string': 'N.D. Okla.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Oklahoma',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.99,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/oknd/',
#   'short_name': 'N.D. Oklahoma',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of Oklahoma',
#   'url': 'http://www.oknd.uscourts.gov/'},
#  {'citation_string': 'W.D. Ark.',
#   'date_modified': '2013-10-22T15:48:19.676000Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Arkansas',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 204.2,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/arwd/',
#   'short_name': 'W.D. Arkansas',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Arkansas',
#   'url': 'http://www.arwd.uscourts.gov/'},
#  {'citation_string': '6th Cir.',
#   'date_modified': '2014-11-07T21:21:10.610000Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the Sixth Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': True,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 106.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ca6/',
#   'short_name': 'Sixth Circuit',
#   'start_date': '1891-03-03',
#   'unabbreviated_name': 'United States Court of Appeals for the Sixth Circuit',
#   'url': 'http://www.ca6.uscourts.gov/'},
#  {'citation_string': 'S.D.W. Va',
#   'date_modified': '2017-03-16T18:51:45.638841Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. West Virginia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 295.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/wvsd/',
#   'short_name': 'S.D. West Virginia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of West Virginia',
#   'url': 'http://www.wvsd.uscourts.gov/'},
#  {'citation_string': 'W.D. Pa.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Pennsylvania',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 248.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/pawd/',
#   'short_name': 'W.D. Pennsylvania',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Pennsylvania',
#   'url': 'http://www.pawd.uscourts.gov/'},
#  {'citation_string': 'D.C. Cir.',
#   'date_modified': '2014-10-31T01:58:53.255000Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the D.C. Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': True,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 112.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/cadc/',
#   'short_name': 'D.C. Circuit',
#   'start_date': '1893-02-09',
#   'unabbreviated_name': 'United States Court of Appeals for the D.C. Circuit',
#   'url': 'http://www.cadc.uscourts.gov/'},
#  {'citation_string': 'Ct. Cl.',
#   'date_modified': '2013-10-18T00:47:36.613000Z',
#   'end_date': '1992-10-29',
#   'full_name': 'United States Court of Claims',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 113.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/cc/',
#   'short_name': 'Court of Claims',
#   'start_date': '1855-02-24',
#   'unabbreviated_name': 'United States Court of Claims',
#   'url': 'http://www.fjc.gov/history/home.nsf/page/courts_special_coc.html'},
#  {'citation_string': 'E.D. Va.',
#   'date_modified': '2013-08-14T22:23:54Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. Virginia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 279.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/vaed/',
#   'short_name': 'E.D. Virginia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Eastern District of Virginia',
#   'url': 'http://www.vaed.uscourts.gov/'},
#  {'citation_string': '7th Cir.',
#   'date_modified': '2014-10-31T01:58:20.448000Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the Seventh Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': True,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 107.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ca7/',
#   'short_name': 'Seventh Circuit',
#   'start_date': '1891-03-03',
#   'unabbreviated_name': 'United States Court of Appeals for the Seventh Circuit',
#   'url': 'http://www.ca7.uscourts.gov/'},
#  {'citation_string': 'E.D. Cal.',
#   'date_modified': '2014-06-13T18:53:09.142000Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. California',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 205.06,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/caed/',
#   'short_name': 'E.D. California',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Eastern District of California',
#   'url': 'http://www.caed.uscourts.gov/'},
#  {'citation_string': 'M.D. Tenn.',
#   'date_modified': '2013-10-22T15:25:43.332000Z',
#   'end_date': None,
#   'full_name': 'District Court, M.D. Tennessee',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 249.7,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/tnmd/',
#   'short_name': 'M.D. Tennessee',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Middle District of Tennessee',
#   'url': 'http://www.tnmd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, M.D. Georgia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 208.6,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/gamd/',
#   'short_name': 'M.D. Georgia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Middle District of Georgia',
#   'url': 'http://www.gamd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:11:18.510098Z',
#   'end_date': None,
#   'full_name': 'District Court, D. North Carolina',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 245.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ncd/',
#   'short_name': 'D. North Carolina',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of North Carolina',
#   'url': ''},
#  {'citation_string': 'D. Minnesota',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Minnesota',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 241.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mnd/',
#   'short_name': 'D. Minnesota',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Minnesota',
#   'url': 'http://www.mnd.uscourts.gov/'},
#  {'citation_string': 'Mo. S.D.',
#   'date_modified': '2013-10-30T07:51:33.340000Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Missouri',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 242.15,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mosd/',
#   'short_name': 'S.D. Missouri',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of Missouri',
#   'url': 'http://www.courts.mo.gov/page.jsp?id=208\u200e'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:01:30.544169Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Alabama',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 200.9,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ald/',
#   'short_name': 'D. Alabama',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Alabama',
#   'url': ''},
#  {'citation_string': 'D. Ind.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': '1928-04-21',
#   'full_name': 'District Court, D. Indiana',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 214.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/indianad/',
#   'short_name': 'D. Indiana',
#   'start_date': '1817-03-03',
#   'unabbreviated_name': 'United States District Court for the District of Indiana',
#   'url': 'http://www.insd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:12:14.006335Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Virginia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 278.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/vad/',
#   'short_name': 'D. Virginia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Virginia',
#   'url': ''},
#  {'citation_string': 'N.D.W. Va.',
#   'date_modified': '2013-10-22T15:57:29.828000Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. West Virginia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 294.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/wvnd/',
#   'short_name': 'N.D. West Virginia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of West Virginia',
#   'url': 'http://www.wvnd.uscourts.gov/'},
#  {'citation_string': 'Ct. Intl. Trade',
#   'date_modified': '2013-08-14T22:20:46Z',
#   'end_date': None,
#   'full_name': 'United States Court of International Trade',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 141.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/cit/',
#   'short_name': 'Court of International Trade',
#   'start_date': None,
#   'unabbreviated_name': 'United States Court of International Trade',
#   'url': 'http://www.cit.uscourts.gov/'},
#  {'citation_string': 'M.C.',
#   'date_modified': '2014-11-24T17:05:17.768000Z',
#   'end_date': None,
#   'full_name': 'United States Court of Military Commission Review',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 114.99,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mc/',
#   'short_name': 'Military Commission Review',
#   'start_date': None,
#   'unabbreviated_name': 'United States Court of Military Commission Review',
# ...
#   'short_name': 'S.D. California',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of California',
#   'url': 'http://www.casd.uscourts.gov/'},
#  {'citation_string': 'D.R.I.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Rhode Island',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 248.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/rid/',
#   'short_name': 'D. Rhode Island',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Rhode Island',
#   'url': 'http://www.rid.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2016-03-17T01:01:01Z',
#   'end_date': '1812-04-08',
#   'full_name': 'District Court, Orleans',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 235.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/orld/',
#   'short_name': 'Orleans District Court',
#   'start_date': '1804-10-01',
#   'unabbreviated_name': 'United States District Court for the Orleans',
#   'url': 'https://en.wikipedia.org/wiki/United_States_District_Court_for_the_District_of_Orleans'},
#  {'citation_string': 'S.D. Ohio',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, S.D. Ohio',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.91,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ohsd/',
#   'short_name': 'S.D. Ohio',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Southern District of Ohio',
#   'url': 'http://www.ohsd.uscourts.gov/'},
#  {'citation_string': 'E.D. Okla.',
#   'date_modified': '2013-10-22T15:54:40.816000Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. Oklahoma',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.95,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/oked/',
#   'short_name': 'E.D. Oklahoma',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Eastern District of Oklahoma',
#   'url': 'http://www.oked.uscourts.gov/'},
#  {'citation_string': 'D. Mass.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Massachusetts',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 240.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mad/',
#   'short_name': 'D. Massachusetts',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Massachusetts',
#   'url': 'http://www.mad.uscourts.gov/'},
#  {'citation_string': 'D. Idaho',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Idaho',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 209.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/idd/',
#   'short_name': 'D. Idaho',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Idaho',
#   'url': 'http://www.id.uscourts.gov/'},
#  {'citation_string': 'E.D. La.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. Louisiana.',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 231.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/laed/',
#   'short_name': 'E.D. Louisiana.',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Eastern District of Louisiana.',
#   'url': 'http://www.laed.uscourts.gov/'},
#  {'citation_string': 'D. Ariz.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Arizona',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 203.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/azd/',
#   'short_name': 'D. Arizona',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Arizona',
#   'url': 'http://www.azd.uscourts.gov/'},
#  {'citation_string': 'E.D. Mo.',
#   'date_modified': '2013-10-22T15:53:29.670000Z',
#   'end_date': None,
#   'full_name': 'District Court, E.D. Missouri',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 242.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/moed/',
#   'short_name': 'E.D. Missouri',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Eastern District of Missouri',
#   'url': 'http://www.moed.uscourts.gov/'},
#  {'citation_string': 'W.D. Ky.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Kentucky',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 230.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/kywd/',
#   'short_name': 'W.D. Kentucky',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Kentucky',
#   'url': 'http://www.kywd.uscourts.gov/'},
#  {'citation_string': 'D. Me.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Maine',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 239.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/med/',
#   'short_name': 'D. Maine',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Maine',
#   'url': 'http://www.med.uscourts.gov/'},
#  {'citation_string': 'D.S.D.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. South Dakota',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 249.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/sdd/',
#   'short_name': 'D. South Dakota',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of South Dakota',
#   'url': 'http://www.sdd.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2016-06-29T21:21:26.946503Z',
#   'end_date': '1812-04-30',
#   'full_name': 'Circuit Court for California',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 205.3,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/caca/',
#   'short_name': 'California Circuit',
#   'start_date': '1804-10-01',
#   'unabbreviated_name': 'Circuit Court for California',
#   'url': 'http://www.fjc.gov/history/home.nsf/page/landmark_07.html'},
#  {'citation_string': 'Op. Att’y Gen.',
#   'date_modified': '2017-01-27T22:35:06.131210Z',
#   'end_date': None,
#   'full_name': 'United States Attorneys General',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 113.04,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ag/',
#   'short_name': 'Attorneys General',
#   'start_date': None,
#   'unabbreviated_name': 'United States Attorneys General',
#   'url': 'https://www.justice.gov/olc/opinions-main'},
#  {'citation_string': 'D.P.R.',
#   'date_modified': '2013-08-15T17:00:09Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Puerto Rico',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 299.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/prd/',
#   'short_name': 'D. Puerto Rico',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Puerto Rico',
#   'url': 'http://www.prd.uscourts.gov/'},
#  {'citation_string': 'D.N.H.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. New Hampshire',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 243.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/nhd/',
#   'short_name': 'D. New Hampshire',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of New Hampshire',
#   'url': 'http://www.nhd.uscourts.gov/'},
#  {'citation_string': 'D. Ohio',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': '1855-02-10',
#   'full_name': 'District Court, D. Ohio',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.92,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ohiod/',
#   'short_name': 'D. Ohio',
#   'start_date': '1803-02-19',
#   'unabbreviated_name': 'United States District Court for the District of Ohio',
#   'url': 'http://www.uscourts.gov/'},
#  {'citation_string': 'D. Haw.',
#   'date_modified': '2013-08-15T16:58:25Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Hawaii',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 208.9,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/hid/',
#   'short_name': 'D. Hawaii',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Hawaii',
#   'url': 'http://www.hid.uscourts.gov/'},
#  {'citation_string': 'N.D. Cal.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. California',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 205.1,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/cand/',
#   'short_name': 'N.D. California',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of California',
#   'url': 'http://www.cand.uscourts.gov/'},
#  {'citation_string': '',
#   'date_modified': '2017-03-07T23:12:38.236173Z',
#   'end_date': None,
#   'full_name': 'District Court, D. Washington',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': False,
#   'jurisdiction': 'FD',
#   'position': 288.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/washd/',
#   'short_name': 'D. Washington',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of Washington',
#   'url': ''},
#  {'citation_string': 'Tax Ct.',
#   'date_modified': '2013-08-14T22:20:02Z',
#   'end_date': None,
#   'full_name': 'United States Tax Court',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FS',
#   'position': 114.2,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/tax/',
#   'short_name': 'U.S. Tax Court',
#   'start_date': None,
#   'unabbreviated_name': 'United States Tax Court',
#   'url': 'http://www.ustaxcourt.gov/'},
#  {'citation_string': 'W.D. Va.',
#   'date_modified': '2013-08-14T22:23:54Z',
#   'end_date': None,
#   'full_name': 'District Court, W.D. Virginia',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 280.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/vawd/',
#   'short_name': 'W.D. Virginia',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Western District of Virginia',
#   'url': 'http://www.vawd.uscourts.gov/'},
#  {'citation_string': 'SCOTUS',
#   'date_modified': '2014-10-31T01:59:15.952000Z',
#   'end_date': None,
#   'full_name': 'Supreme Court of the United States',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': True,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 1.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/scotus/',
#   'short_name': 'Supreme Court',
#   'start_date': '1789-09-24',
#   'unabbreviated_name': 'Supreme Court of the United States',
#   'url': 'http://supremecourt.gov/'},
#  {'citation_string': 'Cir. Ct. N.C.',
#   'date_modified': '2016-06-29T17:11:46.596000Z',
#   'end_date': '1912-01-01',
#   'full_name': 'U.S. Circuit Court for the District of Tennessee',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 249.91,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/circttenn/',
#   'short_name': 'Circuit Court of Tennessee',
#   'start_date': '1807-02-24',
#   'unabbreviated_name': 'U.Southern  Circuit Court for the District of Tennessee',
#   'url': 'http://www.fjc.gov/history/home.nsf/page/courts_circuit_tn.html'},
#  {'citation_string': 'N.D. Ohio',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, N.D. Ohio',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.8,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ohnd/',
#   'short_name': 'N.D. Ohio',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Northern District of Ohio',
#   'url': 'http://www.ohnd.uscourts.gov/'},
#  {'citation_string': 'C.D. Mo.',
#   'date_modified': '2013-10-22T15:51:15.355000Z',
#   'end_date': None,
#   'full_name': 'District Court, C.D. Missouri',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 241.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/mocd/',
#   'short_name': 'C.D. Missouri',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the Central District of Missouri',
#   'url': 'http://www.uscourts.gov/'},
#  {'citation_string': 'Cir. Ct. N.C.',
#   'date_modified': '2016-06-29T17:11:46.596000Z',
#   'end_date': '1912-01-01',
#   'full_name': 'U.S. Circuit Court for the District of North Carolina',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 245.25,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/circtnc/',
#   'short_name': 'Circuit Court of North Carolina',
#   'start_date': '1790-06-04',
#   'unabbreviated_name': 'U.Southern  Circuit Court for the District of North Carolina',
#   'url': 'http://www.fjc.gov/history/home.nsf/page/courts_circuit_nc.html'},
#  {'citation_string': 'D.N.J.',
#   'date_modified': '2013-08-14T22:23:53Z',
#   'end_date': None,
#   'full_name': 'District Court, D. New Jersey',
#   'has_opinion_scraper': False,
#   'has_oral_argument_scraper': False,
#   'in_use': True,
#   'jurisdiction': 'FD',
#   'position': 243.5,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/njd/',
#   'short_name': 'D. New Jersey',
#   'start_date': None,
#   'unabbreviated_name': 'United States District Court for the District of New Jersey',
#   'url': 'http://www.njd.uscourts.gov/'},
#  {'citation_string': '3rd Cir.',
#   'date_modified': '2014-10-31T01:57:54.656000Z',
#   'end_date': None,
#   'full_name': 'Court of Appeals for the Third Circuit',
#   'has_opinion_scraper': True,
#   'has_oral_argument_scraper': True,
#   'in_use': True,
#   'jurisdiction': 'F',
#   'position': 103.0,
#   'resource_uri': 'http://www.courtlistener.com/api/rest/v3/courts/ca3/',
#   'short_name': 'Third Circuit',
#   'start_date': '1891-03-03',
#   'unabbreviated_name': 'United States Court of Appeals for the Third Circuit',
#   'url': 'http://www.ca3.uscourts.gov/'}]

# %%
import pandas as pd

df = pd.DataFrame(courts)
df = df.set_index('position').sort_index()

# %%
df
# Out:
#             citation_string                date_modified end_date  \
# position
# 140.00        FISA Ct. Rev.  2014-05-27T15:58:53.457000Z     None
# 156.00     Bankr. N.D. Ala.         2013-08-15T01:21:42Z     None
# 187.00       Bankr. D. Kan.         2013-08-14T23:43:21Z     None
# 189.20    Bankr. W.D. Mich.         2013-08-15T00:48:40Z     None
# 189.35    Bankr. S.D. Miss.         2013-08-15T16:05:56Z     None
# 240.55                       2017-03-07T23:09:13.812273Z     None
# 246.00           W.D. Okla.         2013-08-14T22:23:53Z     None
# 299.40           N. Mar. I.         2013-08-15T19:41:12Z     None
# 322.00                Ariz.         2013-08-14T16:46:30Z     None
# 359.10            Haw. App.         2013-08-14T22:42:16Z     None
#
#                                                   full_name  \
# position
# 140.00    Foreign Intelligence Surveillance Court of Review
# 156.00         United States Bankruptcy Court, N.D. Alabama
# 187.00            United States Bankruptcy Court, D. Kansas
# 189.20        United States Bankruptcy Court, W.D. Michigan
# 189.35     United States Bankruptcy Court, S.D. Mississippi
# 240.55                          District Court, D. Michigan
# 246.00                        District Court, W.D. Oklahoma
# 299.40             District Court, Northern Mariana Islands
# 322.00                                Arizona Supreme Court
# 359.10                 Hawaii Intermediate Court of Appeals
#
#           has_opinion_scraper  has_oral_argument_scraper  in_use jurisdiction  \
# position
# 140.00                  False                      False    True           FS
# 156.00                  False                      False    True           FB
# 187.00                  False                      False    True           FB
# 189.20                  False                      False    True           FB
# 189.35                  False                      False    True           FB
# 240.55                  False                      False   False           FD
# 246.00                  False                      False    True           FD
# 299.40                  False                      False    True           FD
# 322.00                   True                      False    True            S
# 359.10                   True                      False    True           SA
#
#                                                resource_uri  \
# position
# 140.00    http://www.courtlistener.com/api/rest/v3/court...
# 156.00    http://www.courtlistener.com/api/rest/v3/court...
# 187.00    http://www.courtlistener.com/api/rest/v3/court...
# 189.20    http://www.courtlistener.com/api/rest/v3/court...
# 189.35    http://www.courtlistener.com/api/rest/v3/court...
# 240.55    http://www.courtlistener.com/api/rest/v3/court...
# 246.00    http://www.courtlistener.com/api/rest/v3/court...
# 299.40    http://www.courtlistener.com/api/rest/v3/court...
# 322.00    http://www.courtlistener.com/api/rest/v3/court...
# 359.10    http://www.courtlistener.com/api/rest/v3/court...
#
#                                                  short_name  start_date  \
# position
# 140.00    Foreign Intelligence Surveillance Court of Review  1978-10-25
# 156.00                                         N.D. Alabama        None
# 187.00                                            D. Kansas        None
# 189.20                                        W.D. Michigan        None
# 189.35                                     S.D. Mississippi        None
# 240.55                                          D. Michigan        None
# 246.00                                        W.D. Oklahoma        None
# 299.40                             Northern Mariana Islands        None
# 322.00                                Arizona Supreme Court        None
# 359.10                 Hawaii Intermediate Court of Appeals        None
#
#                                                   url
# position
# 140.00                  http://www.fisc.uscourts.gov/
# 156.00                  http://www.alnb.uscourts.gov/
# 187.00                   http://www.ksb.uscourts.gov/
# 189.20                  http://www.miwb.uscourts.gov/
# 189.35                  http://www.mssb.uscourts.gov/
# 240.55
# 246.00                       http://www.uscourts.gov/
# 299.40                  http://www.nmid.uscourts.gov/
# 322.00    http://www.azcourts.gov/azsupremecourt.aspx
# 359.10                 http://www.courts.state.hi.us/

# %%
os.walk(foldername)
# Out:
# <generator object walk at 0x10d1e7308>

# %%
help(os.walk)
# Out:
# Help on function walk in module os:
#
# walk(top, topdown=True, onerror=None, followlinks=False)
#     Directory tree generator.
#
#     For each directory in the directory tree rooted at top (including top
#     itself, but excluding '.' and '..'), yields a 3-tuple
#
#         dirpath, dirnames, filenames
#
#     dirpath is a string, the path to the directory.  dirnames is a list of
#     the names of the subdirectories in dirpath (excluding '.' and '..').
#     filenames is a list of the names of the non-directory files in dirpath.
#     Note that the names in the lists are just names, with no path components.
#     To get a full path (which begins with top) to a file or directory in
#     dirpath, do os.path.join(dirpath, name).
#
#     If optional arg 'topdown' is true or not specified, the triple for a
#     directory is generated before the triples for any of its subdirectories
#     (directories are generated top down).  If topdown is false, the triple
#     for a directory is generated after the triples for all of its
#     subdirectories (directories are generated bottom up).
#
#     When topdown is true, the caller can modify the dirnames list in-place
#     (e.g., via del or slice assignment), and walk will only recurse into the
#     subdirectories whose names remain in dirnames; this can be used to prune the
#     search, or to impose a specific order of visiting.  Modifying dirnames when
#     topdown is false is ineffective, since the directories in dirnames have
#     already been generated by the time dirnames itself is generated. No matter
#     the value of topdown, the list of subdirectories is retrieved before the
#     tuples for the directory and its subdirectories are generated.
#
#     By default errors from the os.scandir() call are ignored.  If
#     optional arg 'onerror' is specified, it should be a function; it
#     will be called with one argument, an OSError instance.  It can
#     report the error to continue with the walk, or raise the exception
#     to abort the walk.  Note that the filename is available as the
#     filename attribute of the exception object.
#
#     By default, os.walk does not follow symbolic links to subdirectories on
#     systems that support them.  In order to get this functionality, set the
#     optional argument 'followlinks' to true.
#
#     Caution:  if you pass a relative pathname for top, don't change the
#     current working directory between resumptions of walk.  walk never
#     changes the current directory, and assumes that the client doesn't
#     either.
#
#     Example:
#
#     import os
#     from os.path import join, getsize
#     for root, dirs, files in os.walk('python/Lib/email'):
#         print(root, "consumes", end="")
#         print(sum([getsize(join(root, name)) for name in files]), end="")
#         print("bytes in", len(files), "non-directory files")
#         if 'CVS' in dirs:
#             dirs.remove('CVS')  # don't visit CVS directories

# %%
import json

courts = json.loads(r.text)

# %%
courts
# Out:
# {'count': 419,
#  'next': 'https://www.courtlistener.com/api/rest/v3/courts/?Authorization=Token+6844d0c4a5c70e28ec91668b51c60422db6250c3&page=2',
#  'previous': None,
#  'results': [{'citation_string': 'SCOTUS',
#    'date_modified': '2014-10-31T01:59:15.952000Z',
#    'end_date': None,
#    'fjc_court_id': '',
#    'full_name': 'Supreme Court of the United States',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 1.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/scotus/',
#    'short_name': 'Supreme Court',
#    'start_date': '1789-09-24',
#    'url': 'http://supremecourt.gov/'},
#   {'citation_string': '1st Cir.',
#    'date_modified': '2014-10-31T01:57:47.787000Z',
#    'end_date': None,
#    'fjc_court_id': '1',
#    'full_name': 'Court of Appeals for the First Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 101.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca1/',
#    'short_name': 'First Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca1.uscourts.gov/'},
#   {'citation_string': '2d Cir.',
#    'date_modified': '2016-09-09T19:11:51.320078Z',
#    'end_date': None,
#    'fjc_court_id': '2',
#    'full_name': 'Court of Appeals for the Second Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 102.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca2/',
#    'short_name': 'Second Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca2.uscourts.gov/'},
#   {'citation_string': '3rd Cir.',
#    'date_modified': '2014-10-31T01:57:54.656000Z',
#    'end_date': None,
#    'fjc_court_id': '3',
#    'full_name': 'Court of Appeals for the Third Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 103.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca3/',
#    'short_name': 'Third Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca3.uscourts.gov/'},
#   {'citation_string': '4th Cir.',
#    'date_modified': '2014-10-31T01:58:02.297000Z',
#    'end_date': None,
#    'fjc_court_id': '4',
#    'full_name': 'Court of Appeals for the Fourth Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 104.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca4/',
#    'short_name': 'Fourth Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca4.uscourts.gov/'},
#   {'citation_string': '5th Cir.',
#    'date_modified': '2014-10-31T01:58:10.879000Z',
#    'end_date': None,
#    'fjc_court_id': '5',
#    'full_name': 'Court of Appeals for the Fifth Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 105.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca5/',
#    'short_name': 'Fifth Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca5.uscourts.gov/'},
#   {'citation_string': '6th Cir.',
#    'date_modified': '2014-11-07T21:21:10.610000Z',
#    'end_date': None,
#    'fjc_court_id': '6',
#    'full_name': 'Court of Appeals for the Sixth Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 106.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca6/',
#    'short_name': 'Sixth Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca6.uscourts.gov/'},
#   {'citation_string': '7th Cir.',
#    'date_modified': '2014-10-31T01:58:20.448000Z',
#    'end_date': None,
#    'fjc_court_id': '7',
#    'full_name': 'Court of Appeals for the Seventh Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 107.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca7/',
#    'short_name': 'Seventh Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca7.uscourts.gov/'},
#   {'citation_string': '8th Cir.',
#    'date_modified': '2014-10-31T01:58:29.750000Z',
#    'end_date': None,
#    'fjc_court_id': '8',
#    'full_name': 'Court of Appeals for the Eighth Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 108.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca8/',
#    'short_name': 'Eighth Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca8.uscourts.gov/'},
#   {'citation_string': '9th Cir.',
#    'date_modified': '2014-10-31T01:58:41.248000Z',
#    'end_date': None,
#    'fjc_court_id': '9',
#    'full_name': 'Court of Appeals for the Ninth Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 109.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca9/',
#    'short_name': 'Ninth Circuit',
#    'start_date': '1891-03-03',
#    'url': 'http://www.ca9.uscourts.gov/'},
#   {'citation_string': '10th Cir.',
#    'date_modified': '2013-08-14T16:46:30Z',
#    'end_date': None,
#    'fjc_court_id': '10',
#    'full_name': 'Court of Appeals for the Tenth Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 110.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca10/',
#    'short_name': 'Tenth Circuit',
#    'start_date': '1929-02-28',
#    'url': 'http://www.ca10.uscourts.gov/'},
#   {'citation_string': '11th Cir.',
#    'date_modified': '2013-08-14T16:46:30Z',
#    'end_date': None,
#    'fjc_court_id': '11',
#    'full_name': 'Court of Appeals for the Eleventh Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 111.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ca11/',
#    'short_name': 'Eleventh Circuit',
#    'start_date': '1980-10-14',
#    'url': 'http://www.ca11.uscourts.gov/'},
#   {'citation_string': 'D.C. Cir.',
#    'date_modified': '2014-10-31T01:58:53.255000Z',
#    'end_date': None,
#    'fjc_court_id': '0',
#    'full_name': 'Court of Appeals for the D.C. Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 112.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/cadc/',
#    'short_name': 'D.C. Circuit',
#    'start_date': '1893-02-09',
#    'url': 'http://www.cadc.uscourts.gov/'},
#   {'citation_string': 'Fed. Cir.',
#    'date_modified': '2014-10-31T01:59:03.099000Z',
#    'end_date': None,
#    'fjc_court_id': '',
#    'full_name': 'Court of Appeals for the Federal Circuit',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': True,
#    'in_use': True,
#    'jurisdiction': 'F',
#    'pacer_court_id': None,
#    'position': 113.0,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/cafc/',
#    'short_name': 'Federal Circuit',
#    'start_date': '1982-04-02',
#    'url': 'http://www.cafc.uscourts.gov/'},
#   {'citation_string': 'Op. Attâ€™y Gen.',
#    'date_modified': '2017-01-27T22:35:06.131210Z',
#    'end_date': None,
#    'fjc_court_id': '',
#    'full_name': 'United States Attorneys General',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'FS',
#    'pacer_court_id': None,
#    'position': 113.04,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/ag/',
#    'short_name': 'Attorneys General',
#    'start_date': None,
#    'url': 'https://www.justice.gov/olc/opinions-main'},
#   {'citation_string': 'A.F.C.C.A.',
#    'date_modified': '2014-09-19T01:41:11.798000Z',
#    'end_date': None,
#    'fjc_court_id': '',
#    'full_name': 'United States Air Force Court of Criminal Appeals',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'FS',
#    'pacer_court_id': None,
#    'position': 113.05,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/afcca/',
#    'short_name': 'Air Force Court of Criminal Appeals',
#    'start_date': None,
#    'url': 'http://afcca.law.af.mil/'},
#   {'citation_string': 'A.S.B.C.A.',
#    'date_modified': '2014-09-19T01:15:36.995000Z',
#    'end_date': None,
#    'fjc_court_id': '',
#    'full_name': 'Armed Services Board of Contract Appeals',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'FS',
#    'pacer_court_id': None,
#    'position': 113.1,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/asbca/',
#    'short_name': 'Armed Services Board of Contract Appeals',
#    'start_date': None,
#    'url': 'http://www.asbca.mil/'},
#   {'citation_string': 'C.A.A.F.',
#    'date_modified': '2013-08-14T22:18:37Z',
#    'end_date': None,
#    'fjc_court_id': '',
#    'full_name': 'Court of Appeals for the Armed Forces',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'FS',
#    'pacer_court_id': None,
#    'position': 113.2,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/armfor/',
#    'short_name': 'Court of Appeals for the Armed Forces',
#    'start_date': '1951-05-31',
#    'url': 'http://www.armfor.uscourts.gov/'},
#   {'citation_string': 'A.C.C.A.',
#    'date_modified': '2015-01-09T00:24:40.715000Z',
#    'end_date': None,
#    'fjc_court_id': '',
#    'full_name': 'Army Court of Criminal Appeals',
#    'has_opinion_scraper': True,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'FS',
#    'pacer_court_id': None,
#    'position': 113.3,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/acca/',
#    'short_name': 'Army Court of Criminal Appeals',
#    'start_date': None,
#    'url': 'https://www.jagcnet.army.mil/ACCA'},
#   {'citation_string': 'Ct. Cl.',
#    'date_modified': '2013-10-18T00:47:36.613000Z',
#    'end_date': '1992-10-29',
#    'fjc_court_id': '',
#    'full_name': 'United States Court of Claims',
#    'has_opinion_scraper': False,
#    'has_oral_argument_scraper': False,
#    'in_use': True,
#    'jurisdiction': 'FS',
#    'pacer_court_id': None,
#    'position': 113.5,
#    'resource_uri': 'https://www.courtlistener.com/api/rest/v3/courts/cc/',
#    'short_name': 'Court of Claims',
#    'start_date': '1855-02-24',
#    'url': 'http://www.fjc.gov/history/home.nsf/page/courts_special_coc.html'}]}
